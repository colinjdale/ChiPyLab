# %%
import numpy as np
R = 1
omega_tilde_factors = (np.sqrt(2) * np.pi * 0.18**2 * (2*np.pi)**4/0.305)**(2/9)

num_factors = omega_tilde_factors**6 * 2 /((2*np.pi)**4 * 0.18**2)

print(num_factors/1e4)
omega_d = 2*np.pi*4e6
C = 1
kF_ell_d = 4*np.pi/1e2
R = 10
factor = ((2*np.pi)**5*R/kF_ell_d/C * 0.18**2/0.42**2)**(1/6)
trf = omega_d**(-1) * factor

trf*1e6
factor
R = 10
C = 1

ratio = (0.026)*(0.42**2) * kF_ell_d/4/np.pi * R**(1/3) /C**(1/3)
ratio
(0.18**2 * (2*np.pi)**4 * np.sqrt(2)*np.pi / 0.305)**(2/9)
4.3*10**(2/9) * 15
# Out:
# 0.02629893722634472
# 107.59248464940379

# %%
import numpy as np
R = 10
C = 1

t = 1

detuning = 2*np.pi**2/C**2 * R**2 * t**2
print(detuning)
# Out:
# 1973.9208802178716

# %%
R = 10
C = 1

# t = 0.1

detuning = 15
# detuning = 2*np.pi**2/C**2 * R**2 * t**2

t = np.sqrt(detuning * C**2 / (2*np.pi**2 * R**2))
print(1/t)
# Out:
# 11.471474419090953

# %%
11*12
# Out:
# 132

# %%
1/0.42**2
# Out:
# 5.6689342403628125

# %%
0.42**2
# Out:
# 0.17639999999999997
